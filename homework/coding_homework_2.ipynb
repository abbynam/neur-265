# %% [markdown]
# <a href="https://colab.research.google.com/github/abbynam/neur-265/blob/main/coding_homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Abby Nam
# #### *NEUR265*
# #### **2/13/2026**

# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
# import csvs & create arrays

v_rest1 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv')
v_rest2 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv')

# %%
# concatenate datasets into smaller matrix

# i used all data here, homework says to make sure shape is (2, 13) but you told us not to in class
v_rest = np.array((v_rest1, v_rest2))

print(v_rest.shape)
# Out:
# (2, 500)

# %%
# print size of v-rest

np.size(v_rest)
# Out:
# 1000

# %%
# return first row
v_rest[0]
# Out:
# array([-68.24292501, -69.60158234, -76.03420105, -71.16118393,
#        -76.35402679, -70.89105013, -64.11880341, -72.8632112 ,
#        -78.96890068, -55.4531032 , -60.98506045, -66.61118807,
#        -67.08294233, -73.90523593, -74.63317594, -49.27067811,
#        -76.05053997, -65.45417595, -58.53314018, -66.28985665,
#        -64.09106996, -71.49303228, -65.11718958, -73.74140637,
#        -74.81462097, -71.32343356, -74.46990373, -65.03939126,
#        -71.94757271, -73.42034054, -71.10602856, -61.28795481,
#        -73.79654069, -64.48533249, -69.65824959, -73.71225967,
#        -85.56860669, -57.49219704, -76.91730436, -62.61127641,
#        -67.08071963, -78.45983535, -78.87342682, -76.14055703,
#        -62.40101166, -72.41336346, -62.03701146, -63.30990855,
#        -62.02654052, -73.0206111 , -63.11713295, -70.05060087,
#        -75.7537974 , -57.15310111, -72.52368011, -70.86691952,
#        -65.435009  , -66.87690226, -70.79107895, -71.34088898,
# ...

# %%
# return sum of vals in 3rd column
print(v_rest[:, 2].sum())
# Out:
# -151.75359464

# %%
# return second to last value in 2nd row v_rest
print(v_rest[1][-2])
# Out:
# -49.80412917

# %%
# make histogram of vals in 1st row v_rest

plt.hist(v_rest[0])
plt.xlabel('Resting membrane potential')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# find mean RMP in sst and pvalb, assign means to new vars

v_rest_mean_sst = st.mean(v_rest[0])
v_rest_mean_pvalb = st.mean(v_rest[1])

print(v_rest_mean_sst)
print(v_rest_mean_pvalb)
# Out:
# -67.73465864056
# -69.97869017908

# %% [markdown]
# ##### Pvalb has a lower/more negative resting membrane potential than sst in this sample.

# %%
# import scipy pkg

import scipy.stats as stats

# %%
# do t-test comparing difference between mean sst and pvalb RMPs

stats.ttest_ind(v_rest[0], v_rest[1])
# Out:
# TtestResult(statistic=np.float64(5.837507010328816), pvalue=np.float64(7.159828660199036e-09), df=np.float64(998.0))

# %% [markdown]
# My p-value was *p* = 7.159828660199036e-09, which is a very small number. Since *p* < 0.05, the mean RMPs for sst and pvalb neurons were significantly different.
