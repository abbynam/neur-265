# %% [markdown]
# <a href="https://colab.research.google.com/github/abbynam/neur-265/blob/main/notebooks/Spatial_Omics_03_05_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RNA-Sequencing: Spatial Transcriptomics
#
# In our last notebook, we covered "single-cell RNA-sequencing", which is a special kind of RNA-sequencing that preserves cell identities (in contrast to bulk RNA-sequencing, which is done with homogenized tissue). In this notebook, we will explore "spatial transcriptomics" - a special instance of RNA-sequencing that lets you preserve the spatial location (along a brain slice, for instance) of gene expression.

# %% [markdown]
# ##By the end of this notebook, you will be able to:
#
# - Perform quality control on spatial transcriptomics data
# - Map genes corresponding to bulk labels onto a brain section
# - Look at how specific genes map onto bulk labeled clusters

# %% [markdown]
# ##Introduction
#
# <img src = 'https://drive.google.com/uc?id=19C8pMr8v68HweyP-SBxP8NkvC1F3_UL2'>
#
# The brain is highly heterogeneous - it contains lots of different types of cells, and these cells are distributed differently in different brain regions.
#
# Sometimes, it's useful to know whether clusters of cells that share common patterns of gene expression are also spatially clustered together in common parts of the brain.
#
# "Spatial transcriptomics" is a technique that lets us achieve this.

# %% [markdown]
# <img src = 'https://drive.google.com/uc?id=16t49zP29crcRrApFc77l5TJ6F76zgn8p'>
#
# Spatial transcriptomics involves performing cDNA synthesis directly onto a slice of tissue (taken, for example, from a brain). The tissue is partitioned into distinct spatial compartments (think of these like dots on a piece of mesh), and cDNA synthesis and RNA-sequencing is performed for each dot. The dots receive a special "barcode" (a unique genetic sequence added), and this barcode is used to place each dot back onto the tissue slice.

# %% [markdown]
# ##Case Study Data
#
# We will be working with a slice of brain from the human medial temporal lobe (MTL).

# %%
# Import your modules!

# !pip install scanpy
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: scanpy in /usr/local/lib/python3.12/dist-packages (1.12)
# Requirement already satisfied: anndata>=0.10.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.12.10)
# Requirement already satisfied: fast-array-utils>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from fast-array-utils[accel,sparse]>=1.2.1->scanpy) (1.3.1)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.15.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.12/dist-packages (from scanpy) (26.0)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.4)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.11)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.10.8->scanpy) (1.14.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.10.8->scanpy) (3.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->scanpy) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9->scanpy) (1.17.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.16.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (6.0.3)

# %% [markdown]
# The function `datasets.visium_sge()` downloads the dataset from 10x Genomics and returns an `AnnData `object that contains counts, images and spatial coordinates. We will calculate standard QC metrics with `pp.calculate_qc_metrics` and percentage of mitochondrial read counts per sample.

# %%
adata = sc.datasets.visium_sge(sample_id="V1_Human_Brain_Section_1")
adata.var_names_make_unique()
adata.var["mt"] = adata.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True)
# Out:
# /tmp/ipykernel_242/131019638.py:1: FutureWarning: Use `squidpy.datasets.visium` instead.
#   adata = sc.datasets.visium_sge(sample_id="V1_Human_Brain_Section_1")
# /usr/local/lib/python3.12/dist-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %% [markdown]
# We should perform some basic filtering of spots (dots on the brain slice) based on total counts and expressed genes.

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 4))
sns.distplot(adata.obs["total_counts"], kde=False, ax=axs[0])
sns.distplot(adata.obs["total_counts"][adata.obs["total_counts"] < 10000], kde=False, bins=40, ax=axs[1])
sns.distplot(adata.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
sns.distplot(adata.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 4000], kde=False, bins=60, ax=axs[3])
# Out:
# /tmp/ipykernel_242/1125004840.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["total_counts"], kde=False, ax=axs[0])
# /tmp/ipykernel_242/1125004840.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["total_counts"][adata.obs["total_counts"] < 10000], kde=False, bins=40, ax=axs[1])
# /tmp/ipykernel_242/1125004840.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
# /tmp/ipykernel_242/1125004840.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 4000], kde=False, bins=60, ax=axs[3])
# <Axes: xlabel='n_genes_by_counts'>

# %% [markdown]
# We'll use our histograms to apply some cutoffs to get rid of cells with abnormally low/large levels of gene expression.

# %%
sc.pp.filter_cells(adata, min_counts=500)
sc.pp.filter_cells(adata, max_counts=20000)
adata = adata[adata.obs["pct_counts_mt"] < 20]
print(f"#cells after MT filter: {adata.n_obs}")
sc.pp.filter_genes(adata, min_cells=10)
# Out:
# #cells after MT filter: 4027
# /usr/local/lib/python3.12/dist-packages/scanpy/preprocessing/_simple.py:278: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %% [markdown]
# We proceed to normalize Visium counts data with the built-in `normalize_total` method from `Scanpy`, and detect highly-variable genes (for later).

# %%
sc.pp.normalize_total(adata, inplace=True)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, flavor="seurat", n_top_genes=2000)

# %% [markdown]
# ##Clustering Gene Sets
#
# To embed and cluster the manifold encoded by transcriptional similarity, we proceed as in the last notebook by making UMAP plots, and attempting to create clusters in state space based on common patterns of gene expression:

# %%
# !pip install leidenalg
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata, key_added="clusters")
# Out:
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: igraph<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from leidenalg) (1.0.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph<2.0,>=1.0.0->leidenalg) (1.7.0)
# /tmp/ipykernel_242/1857490356.py:5: FutureWarning: The `igraph` implementation of leiden clustering is *orders of magnitude faster*. Set the flavor argument to (and install if needed) 'igraph' to use it.
# In the future, the default backend for leiden will be igraph instead of leidenalg. To achieve the future defaults please pass: `flavor='igraph'` and `n_iterations=2`. `directed` must also be `False` to work with igraph’s implementation.
#   sc.tl.leiden(adata, key_added="clusters")

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata, color=["total_counts", "n_genes_by_counts", "clusters"], wspace=0.4)

# %% [markdown]
# ##Visualization in Spatial Coordinates
#
# Let's now try and map the clusters we came up with back onto the original slice of the human brain:

# %%
plt.rcParams["figure.figsize"] = (8, 8)
sc.pl.spatial(adata, img_key="hires", color=["total_counts", "n_genes_by_counts"])
# Out:
# /tmp/ipykernel_242/2709366047.py:2: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata, img_key="hires", color=["total_counts", "n_genes_by_counts"])

# %% [markdown]
# Before, we performed clustering in gene expression space, and visualized the results with UMAP. By visualizing clustered samples in spatial dimensions, we can gain insights into tissue organization and, potentially, into inter-cellular communication.

# %%
sc.pl.spatial(adata, img_key="hires", color="clusters", size=1.5)
# Out:
# /tmp/ipykernel_242/1586445018.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata, img_key="hires", color="clusters", size=1.5)

# %% [markdown]
# ##Cluster Marker Genes
#
# Let us further inspect cluster 5, which occurs along the middle of the image. We can pull out the marker genes for this cluster:

# %%
sc.tl.rank_genes_groups(adata, "clusters", method="t-test")
sc.pl.rank_genes_groups_heatmap(adata, groups="5", n_genes=10, groupby="clusters")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_clusters). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: 5

# %% [markdown]
# And plot the top marker gene ('FOS') to see if its spatial expression pattern recapitulates the cluster's expression pattern:

# %%
sc.pl.spatial(adata, img_key="hires", color=["clusters", "FOS"])
# Out:
# /tmp/ipykernel_242/4052409191.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata, img_key="hires", color=["clusters", "FOS"])

# %% [markdown]
# ><b>Task:</b> Try all of this with "V1_Human_Brain_Section_2". Do you get different clusters? Try pulling out the top expressed genes for a couple of clusters - are they the same as in the first brain slice? Do you think that genetically-distinct neurons in the human brain are spatially organized?

# %%
# import brain section 2

adata2 = sc.datasets.visium_sge(sample_id="V1_Human_Brain_Section_2")
adata2.var_names_make_unique()
adata2.var["mt"] = adata2.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(adata2, qc_vars=["mt"], inplace=True)
# Out:
# /tmp/ipykernel_242/2505576573.py:3: FutureWarning: Use `squidpy.datasets.visium` instead.
#   adata2 = sc.datasets.visium_sge(sample_id="V1_Human_Brain_Section_2")
# /usr/local/lib/python3.12/dist-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 4))
sns.distplot(adata2.obs["total_counts"], kde=False, ax=axs[0])
sns.distplot(adata2.obs["total_counts"][adata.obs["total_counts"] < 14000], kde=False, bins=40, ax=axs[1])
sns.distplot(adata2.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
sns.distplot(adata2.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 6000], kde=False, bins=60, ax=axs[3])
# Out:
# /tmp/ipykernel_242/3355904231.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata2.obs["total_counts"], kde=False, ax=axs[0])
# /tmp/ipykernel_242/3355904231.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata2.obs["total_counts"][adata.obs["total_counts"] < 14000], kde=False, bins=40, ax=axs[1])
# /tmp/ipykernel_242/3355904231.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata2.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
# /tmp/ipykernel_242/3355904231.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata2.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 6000], kde=False, bins=60, ax=axs[3])
# <Axes: xlabel='n_genes_by_counts'>

# %%
sc.pp.filter_cells(adata2, min_counts=500)
sc.pp.filter_cells(adata2, max_counts=20000)
adata2 = adata2[adata2.obs["pct_counts_mt"] < 20]
print(f"#cells after MT filter: {adata2.n_obs}")
sc.pp.filter_genes(adata2, min_cells=10)
# Out:
# #cells after MT filter: 4320
# /usr/local/lib/python3.12/dist-packages/scanpy/preprocessing/_simple.py:278: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %%
sc.pp.normalize_total(adata2, inplace=True)
sc.pp.log1p(adata2)
sc.pp.highly_variable_genes(adata2, flavor="seurat", n_top_genes=2000)

# %%
# !pip install leidenalg
sc.pp.pca(adata2)
sc.pp.neighbors(adata2)
sc.tl.umap(adata2)
sc.tl.leiden(adata2, key_added="clusters")
# Out:
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: igraph<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from leidenalg) (1.0.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph<2.0,>=1.0.0->leidenalg) (1.7.0)
# /tmp/ipykernel_242/1615500118.py:5: FutureWarning: The `igraph` implementation of leiden clustering is *orders of magnitude faster*. Set the flavor argument to (and install if needed) 'igraph' to use it.
# In the future, the default backend for leiden will be igraph instead of leidenalg. To achieve the future defaults please pass: `flavor='igraph'` and `n_iterations=2`. `directed` must also be `False` to work with igraph’s implementation.
#   sc.tl.leiden(adata2, key_added="clusters")

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata2, color=["total_counts", "n_genes_by_counts", "clusters"], wspace=0.4)

# %%
sc.tl.rank_genes_groups(adata2, "clusters", method="t-test")
sc.pl.rank_genes_groups_heatmap(adata2, groups="5", n_genes=10, groupby="clusters")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_clusters). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: 5

# %%
sc.pl.spatial(adata2, img_key="hires", color=["clusters", "PVALB"])
# Out:
# /tmp/ipykernel_242/4241548657.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata2, img_key="hires", color=["clusters", "PVALB"])

# %%
sc.pl.spatial(adata2, img_key="hires", color=["clusters", "SST"])
# Out:
# /tmp/ipykernel_242/123530864.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata2, img_key="hires", color=["clusters", "SST"])

# %% [markdown]
# I got one extra cluster that I didn't have in Section 1. There's a lot less differentiation in this specific slice compared to the first one we looked at. For the most part, it still looks like genetically distinct neurons are spatially organized — cluster 1 is pretty homogenous on the outskirts of this visualization.

# %% [markdown]
# ><b>Task:</b> Try the same thing with a section of the mouse brain - you can try "V1_Adult_Mouse_Brain_Coronal_Section_1", or "V1_Adult_Mouse_Brain_Coronal_Section_2".

# %%
# import mouse brain section 1

adata3 = sc.datasets.visium_sge(sample_id="V1_Adult_Mouse_Brain_Coronal_Section_1")
adata3.var_names_make_unique()
adata3.var["mt"] = adata3.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(adata3, qc_vars=["mt"], inplace=True)
# Out:
# /tmp/ipykernel_242/1209450487.py:3: FutureWarning: Use `squidpy.datasets.visium` instead.
#   adata3 = sc.datasets.visium_sge(sample_id="V1_Adult_Mouse_Brain_Coronal_Section_1")
#   0%|          | 0.00/6.08M [00:00<?, ?B/s]
#   0%|          | 0.00/16.7M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 4))
sns.distplot(adata3.obs["total_counts"], kde=False, ax=axs[0])
sns.distplot(adata3.obs["total_counts"][adata.obs["total_counts"] < 14000], kde=False, bins=40, ax=axs[1])
sns.distplot(adata3.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
sns.distplot(adata3.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 6000], kde=False, bins=60, ax=axs[3])
# Out:
# /tmp/ipykernel_242/2117362345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata3.obs["total_counts"], kde=False, ax=axs[0])
# /tmp/ipykernel_242/2117362345.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata3.obs["total_counts"][adata.obs["total_counts"] < 14000], kde=False, bins=40, ax=axs[1])
# /tmp/ipykernel_242/2117362345.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata3.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
# /tmp/ipykernel_242/2117362345.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata3.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 6000], kde=False, bins=60, ax=axs[3])
# <Axes: xlabel='n_genes_by_counts'>

# %%
sc.pp.filter_cells(adata3, min_counts=500)
sc.pp.filter_cells(adata3, max_counts=20000)
adata3 = adata3[adata3.obs["pct_counts_mt"] < 20]
print(f"#cells after MT filter: {adata3.n_obs}")
sc.pp.filter_genes(adata3, min_cells=10)
# Out:
# #cells after MT filter: 2574
# /usr/local/lib/python3.12/dist-packages/scanpy/preprocessing/_simple.py:278: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %%
sc.pp.normalize_total(adata3, inplace=True)
sc.pp.log1p(adata3)
sc.pp.highly_variable_genes(adata3, flavor="seurat", n_top_genes=2000)

# %%
# !pip install leidenalg
sc.pp.pca(adata3)
sc.pp.neighbors(adata3)
sc.tl.umap(adata3)
sc.tl.leiden(adata3, key_added="clusters")
# Out:
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: igraph<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from leidenalg) (1.0.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph<2.0,>=1.0.0->leidenalg) (1.7.0)
# /tmp/ipykernel_242/3159689165.py:5: FutureWarning: The `igraph` implementation of leiden clustering is *orders of magnitude faster*. Set the flavor argument to (and install if needed) 'igraph' to use it.
# In the future, the default backend for leiden will be igraph instead of leidenalg. To achieve the future defaults please pass: `flavor='igraph'` and `n_iterations=2`. `directed` must also be `False` to work with igraph’s implementation.
#   sc.tl.leiden(adata3, key_added="clusters")

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata3, color=["total_counts", "n_genes_by_counts", "clusters"], wspace=0.4)

# %%
sc.tl.rank_genes_groups(adata3, "clusters", method="t-test")
sc.pl.rank_genes_groups_heatmap(adata3, groups="5", n_genes=10, groupby="clusters")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_clusters). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: 5

# %%
sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Mbp"])
# Out:
# /tmp/ipykernel_242/4049236036.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Mbp"])

# %%
sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Pvalb"])
# Out:
# /tmp/ipykernel_242/1622191407.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Pvalb"])

# %%
sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Sst"])
# Out:
# /tmp/ipykernel_242/888084348.py:1: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(adata3, img_key="hires", color=["clusters", "Sst"])

# %% [markdown]
# I got a bunch of extra clusters that I didn't have compared to the human brain. The mapping and the slice of the brain that we're looking at looks a lot more like a part of the brain. Even though there's a lot more clusters in the mouse brain, there's more distinct differentiation between clusters in my opinion for the mouse section compared to the human section of the brain.
